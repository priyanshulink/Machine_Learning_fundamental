# %% [markdown]
# ***1. Import Pandas***

# %%
import pandas as pd

# %% [markdown]
# ***2. Opening a local csv file***

# %%
df = pd.read_csv("/content/anime.csv")
df
# Out:
#     Rank                                              Title  Score
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02
# 12    13  Bleach: Sennen Kessen-hen - Ketsubetsu-tanTV (...   8.99
# ...

# %% [markdown]
# ***3. Opening a csv file from URL***

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# ***4. Sap Parameter***
#
# By defalt read_csv as sep paremeter is sep=',' but in .tsv file is seperated with '\t' means tab[link text](https://)

# %%
df = pd.read_csv("/content/file.tsv", sep='\t',names=['NO','Rollno.','number','contect'])
df
# Out:
#          NO  Rollno.  number    contect
# 0         0       50       5  881250949
# 1         0      172       5  881250949
# 2         0      133       1  881250949
# 3       196      242       3  881250949
# 4       186      302       3  891717742
# ...     ...      ...     ...        ...
# 99998   880      476       3  880175444
# 99999   716      204       5  879795543
# 100000  276     1090       1  874795795
# 100001   13      225       2  882399156
# 100002   12      203       3  879959583
#
# [100003 rows x 4 columns]

# %% [markdown]
# ***Index_col parameter***
#
# Aisa index jo analysis me kaam n aaye to use aap chaho to index me badal sakte hai

# %%
pd.read_csv("/content/anime.csv", index_col="Rank")
# Out:
#                                                   Title  Score
# Rank
# 1     Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 2     Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 3     Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 4     Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 5     Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05
# 6     Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04
# 7     Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04
# 8     Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04
# 9     Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04
# 10    Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03
# 11    Shingeki no Kyojin: The Final Season - Kankets...   9.03
# 12    Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02
# 13    Bleach: Sennen Kessen-hen - Ketsubetsu-tanTV (...   8.99
# 14    Fruits Basket: The FinalTV (13 eps)Apr 2021 - ...   8.99
# ...

# %% [markdown]
# ***Header Parameter***
#
# tell the parameter which row contain the column name

# %%
url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
df = pd.read_csv(url,header = 1)
df
# Out:
#        Algeria         AFRICA
# 0       Angola         AFRICA
# 1        Benin         AFRICA
# 2     Botswana         AFRICA
# 3      Burkina         AFRICA
# 4      Burundi         AFRICA
# ..         ...            ...
# 188   Paraguay  SOUTH AMERICA
# 189       Peru  SOUTH AMERICA
# 190   Suriname  SOUTH AMERICA
# 191    Uruguay  SOUTH AMERICA
# 192  Venezuela  SOUTH AMERICA
#
# [193 rows x 2 columns]

# %% [markdown]
# ***use_cols parameter ***
#
# data import karte time he hame jo col chaheye vo data ko bata sakte hai aur baki automatically hat jaeyega

# %%
pd.read_csv("/content/aug_train-selected-columns.csv", usecols=['enrollee_id', 'city', 'gender','education_level' ])
# Out:
#      enrollee_id  city  gender  education_level
# 0            NaN   NaN     NaN              NaN
# 1            NaN   NaN     NaN              NaN
# 2            NaN   NaN     NaN              NaN
# 3            NaN   NaN     NaN              NaN
# 4            NaN   NaN     NaN              NaN
# ..           ...   ...     ...              ...
# 119          NaN   NaN     NaN              NaN
# 120          NaN   NaN     NaN              NaN
# 121          NaN   NaN     NaN              NaN
# 122          NaN   NaN     NaN              NaN
# 123          NaN   NaN     NaN              NaN
#
# [124 rows x 4 columns]

# %% [markdown]
# ***Encoding parameter ***
#
# The encoding parameter in pandas.read_csv() tells Pandas how the text in the file is encoded

# %%
pd.read_csv("/content/reviews.csv", encoding='latin-1')
# Out:
#      Index             Name Overall_Rating  \
# 0        0     Oliver Brown            3.9
# 1        1     Oliver Brown            3.9
# 2        2     Crush Coffee              3
# 3        3      The Mohalla            3.8
# 4        4      The Mohalla            3.8
# ..     ...              ...            ...
# 770    770  The Food Garden              -
# 771    771  The Food Garden              -
# 772    772  The Food Garden              -
# 773    773  The Food Garden              -
# 774    774  The Food Garden              -
#
#                                                Cuisine Rate for two  \
# 0    Cafe, Coffee, Shake, Juices, Beverages, Waffle...          500
# 1    Cafe, Coffee, Shake, Juices, Beverages, Waffle...          500
# 2                     Cafe, Shake, Beverages, Desserts          600
# 3                                                 Cafe          550
# 4                                                 Cafe          550
# ...
