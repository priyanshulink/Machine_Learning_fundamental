# %%
import pandas as pd

# %%
# %pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
res = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
 res.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/ezbrL1dMymKQZw7mDEWa2ZTzN7d.jpg',
#   'genre_ids': [16, 28, 12, 14],
#   'id': 980431,
#   'title': 'Avatar Aang: The Last Airbender',
#   'original_language': 'en',
#   'original_title': 'Avatar Aang: The Last Airbender',
#   'overview': "Avatar Aang, the world's last Airbender, learns of an ancient power that could save his culture from extinction. With the help of his friends, he embarks on a global quest to find it before it falls into the wrong hands and threatens to upend the peace they sacrificed everything to achieve.",
#   'popularity': 175.1395,
#   'poster_path': '/3sgnSfNT27Bx5O5ukr7B26mhEQq.jpg',
#   'release_date': '2026-07-24',
#   'softcore': False,
#   'video': False,
#   'vote_average': 9.28,
#   'vote_count': 763},
#  {'adult': False,
#   'backdrop_path': '/iCML6fBe3X0y06P33bM7dyYXPKZ.jpg',
#   'genre_ids': [35, 10749],
#   'id': 1632181,
#   'title': 'Accidental Partners',
#   'original_language': 'es',
# ...

# %%
# to get particular key form data
#  res.json()['results']

# %%
pd.DataFrame(res.json()['results'])
# Out:
#     adult                     backdrop_path            genre_ids       id  \
# 0   False  /ezbrL1dMymKQZw7mDEWa2ZTzN7d.jpg     [16, 28, 12, 14]   980431
# 1   False  /iCML6fBe3X0y06P33bM7dyYXPKZ.jpg          [35, 10749]  1632181
# 2   False   /zMwhWailP1WY7sb6AoE6b8ugoy.jpg  [12, 16, 10751, 14]  1007757
# 3   False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg             [18, 80]      278
# 4   False  /ufSwlnECLoUbBjPrFqEQcWBzHwc.jpg          [10402, 18]   936075
# 5   False  /tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg             [18, 80]      238
# 6   False  /1RgPyOhN4DRs225BGTlHJqCudII.jpg         [16, 28, 14]  1311031
# 7   False  /8Tfys3mDZVp4tNoH2ktm06a0Tau.jpg            [878, 12]   687163
# 8   False  /3HaqAPZ0C8n6Hd5T86U53yJlBAN.jpg          [18, 10749]  1232449
# 9   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg             [18, 80]      240
# 10  False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg      [18, 36, 10752]      424
# 11  False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg                 [18]      389
# ...

# %%
temp_df = pd.DataFrame(res.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df = df.head()

# %%
# create empty dataFrame
df = pd.DataFrame()

# %%
# using loop to call data form api
for i in range(1,429):
    res = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')
    temp_df = pd.DataFrame(res.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

    # appand this temp_df to original df

    pd.concat([df,temp_df], ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# ...

# %%
# you can check shape of this data set
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 # you can check shape of this data set
# ----> 2 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
#import it into csv file 
df.to_csv("movies data")
