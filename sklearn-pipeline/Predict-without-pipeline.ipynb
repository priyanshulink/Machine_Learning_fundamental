# %%
import pickle
import numpy as np

# %%
ohe_sex = pickle.load(open('models/ohe_sex.pkl','rb'))
ohe_embarked = pickle.load(open('models/ohe_embarked.pkl','rb'))
clf = pickle.load(open('models/clf.pkl','rb'))

# %%
# Assume user input
# Pclass/gender/age/sibsb/parch/fare/embarked
test_input =np.array([2,'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)

# %%
test_input
# Out:
# array([[2, 'male', 31.0, 0, 0, 10.5, 'S']], dtype=object)

# %%
test_input_sex = ohe_sex.transform(
    pd.DataFrame([[test_input[0, 1]]], columns=['Sex'])
)

test_input_embarked = ohe_embarked.transform(
    pd.DataFrame([[test_input[0, 6]]], columns=['Embarked'])
)

# %%
test_input_sex
# Out:
# array([[0., 1.]])

# %%
test_input_embarked
# Out:
# array([[0., 0., 1., 0.]])

# %%
test_input_age = test_input[:,2].reshape(1,1)

# %%
test_input_age
# Out:
# array([[31.0]], dtype=object)

# %%
#concatenate test_input_sex, test_input_embarked, test_input_age
test_input_transformed = np.concatenate((test_input[:,[0,3,4,5]],test_input_age,test_input_sex,test_input_embarked),axis=1)

# %%
test_input_transformed.shape
# Out:
# (1, 11)

# %%
clf.predict(test_input_transformed)
# Out:
# array([0])
